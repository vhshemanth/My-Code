# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('nba_2013.csv')

# %%
df.head()
# Out:
#           player pos  age bref_team_id   g  gs    mp   fg   fga    fg.  ...  \
# 0     Quincy Acy  SF   23          TOT  63   0   847   66   141  0.468  ...
# 1   Steven Adams   C   20          OKC  81  20  1197   93   185  0.503  ...
# 2    Jeff Adrien  PF   27          TOT  53  12   961  143   275  0.520  ...
# 3  Arron Afflalo  SG   28          ORL  73  73  2552  464  1011  0.459  ...
# 4  Alexis Ajinca   C   25          NOP  56  30   951  136   249  0.546  ...
#
#    drb  trb  ast  stl  blk  tov   pf   pts     season  season_end
# 0  144  216   28   23   26   30  122   171  2013-2014        2013
# 1  190  332   43   40   57   71  203   265  2013-2014        2013
# 2  204  306   38   24   36   39  108   362  2013-2014        2013
# 3  230  262  248   35    3  146  136  1330  2013-2014        2013
# 4  183  277   40   23   46   63  187   328  2013-2014        2013
#
# [5 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['player', 'pos', 'age', 'bref_team_id', 'g', 'gs', 'mp', 'fg', 'fga',
#        'fg.', 'x3p', 'x3pa', 'x3p.', 'x2p', 'x2pa', 'x2p.', 'efg.', 'ft',
#        'fta', 'ft.', 'orb', 'drb', 'trb', 'ast', 'stl', 'blk', 'tov', 'pf',
#        'pts', 'season', 'season_end'],
#       dtype='object')

# %%
df.describe().T
# Out:
#             count         mean         std     min          25%          50%  \
# age         481.0    26.509356    4.198265    19.0    23.000000    26.000000
# g           481.0    53.253638   25.322711     1.0    32.000000    61.000000
# gs          481.0    25.571726   29.658465     0.0     0.000000    10.000000
# mp          481.0  1237.386694  897.258840     1.0   388.000000  1141.000000
# fg          481.0   192.881497  171.832793     0.0    47.000000   146.000000
# fga         481.0   424.463617  368.850833     0.0   110.000000   332.000000
# fg.         479.0     0.436436    0.098672     0.0     0.400500     0.438000
# x3p         481.0    39.613306   50.855639     0.0     0.000000    16.000000
# x3pa        481.0   110.130977  132.751732     0.0     3.000000    48.000000
# x3p.        414.0     0.285111    0.157633     0.0     0.234355     0.330976
# x2p         481.0   153.268191  147.223161     0.0    31.000000   110.000000
# ...

# %%
df.isnull().sum()
# Out:
# player           0
# pos              0
# age              0
# bref_team_id     0
# g                0
# gs               0
# mp               0
# fg               0
# fga              0
# fg.              2
# x3p              0
# x3pa             0
# x3p.            67
# x2p              0
# x2pa             0
# x2p.             3
# efg.             2
# ft               0
# fta              0
# ft.             20
# orb              0
# drb              0
# trb              0
# ast              0
# stl              0
# blk              0
# tov              0
# pf               0
# pts              0
# season           0
# season_end       0
# dtype: int64

# %%
df.shape
# Out:
# (481, 31)

# %%
df['x3p.']=df['x3p.'].fillna(df['x3p.'].mean())
df['ft.']=df['ft.'].fillna(df['ft.'].mean())
df['fg.']=df['fg.'].fillna(df['fg.'].mean())

# %%
df.isnull().sum()
# Out:
# player          0
# pos             0
# age             0
# bref_team_id    0
# g               0
# gs              0
# mp              0
# fg              0
# fga             0
# fg.             0
# x3p             0
# x3pa            0
# x3p.            0
# x2p             0
# x2pa            0
# x2p.            3
# efg.            2
# ft              0
# fta             0
# ft.             0
# orb             0
# drb             0
# trb             0
# ast             0
# stl             0
# blk             0
# tov             0
# pf              0
# pts             0
# season          0
# season_end      0
# dtype: int64

# %%
df.drop(['player','pos','age','bref_team_id','season','season_end'],axis=1,inplace=True)

# %%
df.head()
# Out:
#     g  gs    mp   fg   fga    fg.  x3p  x3pa      x3p.  x2p  ...    ft.  orb  \
# 0  63   0   847   66   141  0.468    4    15  0.266667   62  ...  0.660   72
# 1  81  20  1197   93   185  0.503    0     0  0.285111   93  ...  0.581  142
# 2  53  12   961  143   275  0.520    0     0  0.285111  143  ...  0.639  102
# 3  73  73  2552  464  1011  0.459  128   300  0.426667  336  ...  0.815   32
# 4  56  30   951  136   249  0.546    0     1  0.000000  136  ...  0.836   94
#
#    drb  trb  ast  stl  blk  tov   pf   pts
# 0  144  216   28   23   26   30  122   171
# 1  190  332   43   40   57   71  203   265
# 2  204  306   38   24   36   39  108   362
# 3  230  262  248   35    3  146  136  1330
# 4  183  277   40   23   46   63  187   328
#
# [5 rows x 25 columns]

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True,linewidths=.1)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
for x in df.columns:
    sns.distplot(df[x])
    plt.show()
# Out:
# C:\Users\vhshe\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\vhshe\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
X=df.drop(['pts'],axis=1)
y=df['pts']

# %%
from sklearn.feature_selection import VarianceThreshold
var_thresh=VarianceThreshold(threshold=0)
var_thresh.fit(X)
# Out:
# VarianceThreshold(threshold=0)

# %%
var_thresh.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True])

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=X)
# Out:
# <AxesSubplot:>

# %%
q = X['fg'].quantile(0.99)
data=X.copy()
# we are removing the top 2% data 
data_cleaned = data[data['fg']<q]
q = data_cleaned['x3p'].quantile(0.99)
# we are removing the top 1% data 
data_cleaned  = data_cleaned[data_cleaned['x3p']<q]
q = data_cleaned['x2p'].quantile(0.99)
# we are removing the top 1% data 
data_cleaned  = data_cleaned[data_cleaned['x2p']<q]

q = data_cleaned['ft'].quantile(0.99)
# we are removing the top 1% data from the BMI column
data_cleaned  = data_cleaned[data_cleaned['ft']<q]
q = data_cleaned['fta'].quantile(0.99)
# we are removing the top 1% data
data_cleaned  = data_cleaned[data_cleaned['fta']<q]
q = data_cleaned['orb'].quantile(0.99)
# we are removing the top 1% data 
data_cleaned  = data_cleaned[data_cleaned['orb']<q]
q = data_cleaned['trb'].quantile(0.99)
# we are removing the top 1% data 
data_cleaned  = data_cleaned[data_cleaned['trb']<q]
q = data_cleaned['ast'].quantile(0.99)
data_cleaned  = data_cleaned[data_cleaned['ast']<q]
q = data_cleaned['stl'].quantile(0.99)
# we are removing the top 1% data 
data_cleaned  = data_cleaned[data_cleaned['stl']<q]
q = data_cleaned['blk'].quantile(0.99)
# we are removing the top 1% data 
data_cleaned  = data_cleaned[data_cleaned['blk']<q]
q = data_cleaned['tov'].quantile(0.99)
# we are removing the top 1% data
data_cleaned  = data_cleaned[data_cleaned['tov']<q]

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=data_cleaned)
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.2,random_state=11)

# %%
X.isnull().sum()
# Out:
# g       0
# gs      0
# mp      0
# fg      0
# fga     0
# fg.     0
# x3p     0
# x3pa    0
# x3p.    0
# x2p     0
# x2pa    0
# x2p.    0
# efg.    0
# ft      0
# fta     0
# ft.     0
# orb     0
# drb     0
# trb     0
# ast     0
# stl     0
# blk     0
# tov     0
# pf      0
# rfg.    0
# dtype: int64

# %%
X['x2p.']=X['x2p.'].fillna(X['x2p.'].mean())
X['efg.']=X['efg.'].fillna(X['efg.'].mean())

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn=KNeighborsRegressor()
knn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
pred=knn.predict(X_test)

# %%
sns.scatterplot(x=y_test,y=pred)
# Out:
# <AxesSubplot:xlabel='pts'>

# %%
knn.score(X_train,y_train)
# Out:
# 0.9817083111045323

# %%
knn.score(X_test,y_test)
# Out:
# 0.9814001720559471

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,pred)
# Out:
# 0.9814001720559471

# %% [markdown]
# We can see that the models is 98% accurate with train and test data

# %% [markdown]
# ## GridSearch CV

# %%
from sklearn.model_selection import GridSearchCV

# %%
KNeighborsRegressor()

# %%
params={"n_neighbors":range(15),
        "weights":['uniform', 'distance'],
        "algorithm" : ['auto', 'ball_tree', 'kd_tree', 'brute']
    
}

# %%
grid=GridSearchCV(knn,param_grid=params,cv=5,n_jobs=-1)

# %%
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsRegressor(), n_jobs=-1,
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'n_neighbors': range(0, 15),
#                          'weights': ['uniform', 'distance']})

# %%
grid.best_params_
# Out:
# {'algorithm': 'auto', 'n_neighbors': 4, 'weights': 'distance'}

# %%
grid.score(X_train,y_train)
# Out:
# 1.0

# %%
grid.score(X_test,y_test)
# Out:
# 0.9818661159852842

# %% [markdown]
# # KFold CV

# %%
from sklearn.model_selection import KFold
kfold = KFold(n_splits=10,random_state= 42)
kfold.get_n_splits(X_scaled)
# Out:
# C:\Users\vhshe\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# 10

# %%
X_scaled = sc.fit_transform(X)

# %%
from statistics import mean
knn = KNeighborsRegressor(algorithm = 'auto', weights ='distance', n_neighbors =4)
cnt =0
count=[]
train_score =[]
test_score = []

for train_index,test_index in kfold.split(X_scaled):
    X_train, X_test = X_scaled[train_index], X_scaled[test_index] # our scaled data is an array so it can work on x[value]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index] # y is a dataframe so we have to use "iloc" to retreive data
    knn.fit(X_train,y_train)
    train_score_ = knn.score(X_train,y_train)
    test_score_ =  knn.score(X_test,y_test)
    cnt+=1
    count.append(cnt)
    train_score.append(train_score_)
    test_score.append(test_score_)
    
    print("for k = ", cnt)
    print("train_score is :  ", train_score_, "and test score is :  ", test_score_)
print("************************************************")
print("************************************************")
print("Average train score is :  ", mean(train_score))
print("Average test score is :  ", mean(test_score))
# Out:
# for k =  1
# train_score is :   1.0 and test score is :   0.9595594849933112
# for k =  2
# train_score is :   1.0 and test score is :   0.9663213304388751
# for k =  3
# train_score is :   1.0 and test score is :   0.9570812312048808
# for k =  4
# train_score is :   1.0 and test score is :   0.9660483953419599
# for k =  5
# train_score is :   1.0 and test score is :   0.9678112046728842
# for k =  6
# train_score is :   1.0 and test score is :   0.9733322756874181
# for k =  7
# train_score is :   1.0 and test score is :   0.9613895080848841
# for k =  8
# train_score is :   1.0 and test score is :   0.9383555413426259
# for k =  9
# train_score is :   1.0 and test score is :   0.9777805605468611
# for k =  10
# train_score is :   1.0 and test score is :   0.9763764840776968
# ************************************************
# ************************************************
# Average train score is :   1.0
# Average test score is :   0.9644056016391397
